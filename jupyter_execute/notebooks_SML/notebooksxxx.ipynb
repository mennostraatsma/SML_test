# %% [markdown]
# # Jupyter notebooks
#
# This is a page to demonstrate the look and feel of Jupyter Notebook elements.
#
#
# ## Hiding elements
#
# ### Hiding inputs

# %%
# Generate some code that we'll use later on in the page
import numpy as np
import matplotlib.pyplot as plt

square = np.random.randn(100, 100)
wide = np.random.randn(100, 1000)

# %%
# Hide input
square = np.random.randn(100, 100)
wide = np.random.randn(100, 1000)


fig, ax = plt.subplots()
ax.imshow(square)

fig, ax = plt.subplots()
ax.imshow(wide)

# %% [markdown]
# ### Hiding outputs

# %%
# Hide output
square = np.random.randn(100, 100)
wide = np.random.randn(100, 1000)

fig, ax = plt.subplots()
ax.imshow(square)

fig, ax = plt.subplots()
ax.imshow(wide)

# %% [markdown]
# ### Hiding markdown
#
# ````{toggle}
# ```{note}
# This is a hidden markdown cell
#
# It should be hidden!
# ```
# ````
#
# ```{admonition} And here's a toggleable note
# :class: dropdown
# With a body!
# ```

# %% [markdown]
# ### Hiding both inputs and outputs

# %%
square = np.random.randn(100, 100)
wide = np.random.randn(100, 1000)

fig, ax = plt.subplots()
ax.imshow(square)

fig, ax = plt.subplots()
ax.imshow(wide)

# %% [markdown]
# ### Hiding the whole cell

# %%
square = np.random.randn(100, 100)
wide = np.random.randn(100, 1000)

fig, ax = plt.subplots()
ax.imshow(square)

fig, ax = plt.subplots()
ax.imshow(wide)

# %% [markdown]
# ## Enriched outputs
#
# ### Math

# %%
# You can also include enriched outputs like Math
from IPython.display import Math
Math("\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}")
# Out:
# $\displaystyle \sum_{i=0}^n i^2 = rac{(n^2+n)(2n+1)}{6}$

# %% [markdown]
# ### Pandas DataFrames

# %%
import pandas as pd
df = pd.DataFrame([['hi', 'there'], ['this', 'is'], ['a', 'DataFrame']], columns=['Word A', 'Word B'])
df
# Out:
#   Word A     Word B
# 0     hi      there
# 1   this         is
# 2      a  DataFrame

# %% [markdown]
# Styled DataFrames (see [the Pandas Styling docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)).

# %%
import pandas as pd

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan

def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df.style.\
    applymap(color_negative_red).\
    apply(highlight_max).\
    set_table_attributes('style="font-size: 10px"')
# Out:
# <style type="text/css">
# #T_ea635_row0_col0, #T_ea635_row0_col1, #T_ea635_row0_col2, #T_ea635_row1_col0, #T_ea635_row1_col3, #T_ea635_row1_col4, #T_ea635_row2_col0, #T_ea635_row2_col2, #T_ea635_row2_col3, #T_ea635_row3_col0, #T_ea635_row3_col1, #T_ea635_row3_col2, #T_ea635_row3_col3, #T_ea635_row3_col4, #T_ea635_row4_col0, #T_ea635_row4_col1, #T_ea635_row4_col2, #T_ea635_row4_col3, #T_ea635_row4_col4, #T_ea635_row5_col0, #T_ea635_row5_col2, #T_ea635_row5_col3, #T_ea635_row6_col0, #T_ea635_row6_col1, #T_ea635_row6_col4, #T_ea635_row7_col0, #T_ea635_row7_col1, #T_ea635_row7_col2, #T_ea635_row7_col4, #T_ea635_row8_col0, #T_ea635_row9_col2, #T_ea635_row9_col4 {
#   color: black;
# }
# #T_ea635_row0_col3, #T_ea635_row0_col4, #T_ea635_row1_col1, #T_ea635_row1_col2, #T_ea635_row2_col1, #T_ea635_row5_col1, #T_ea635_row5_col4, #T_ea635_row6_col3, #T_ea635_row7_col3, #T_ea635_row8_col2, #T_ea635_row8_col4, #T_ea635_row9_col1, #T_ea635_row9_col3 {
#   color: red;
# }
# #T_ea635_row2_col4, #T_ea635_row6_col2, #T_ea635_row8_col1, #T_ea635_row8_col3, #T_ea635_row9_col0 {
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_ea635" style="font-size: 10px">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea635_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ea635_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ea635_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ea635_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_ea635_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea635_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea635_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ea635_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_ea635_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_ea635_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_ea635_row0_col4" class="data row0 col4" >-0.990810</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea635_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_ea635_row1_col1" class="data row1 col1" >-1.070816</td>
#       <td id="T_ea635_row1_col2" class="data row1 col2" >-1.438713</td>
#       <td id="T_ea635_row1_col3" class="data row1 col3" >0.564417</td>
#       <td id="T_ea635_row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea635_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_ea635_row2_col1" class="data row2 col1" >-1.626404</td>
#       <td id="T_ea635_row2_col2" class="data row2 col2" >0.219565</td>
#       <td id="T_ea635_row2_col3" class="data row2 col3" >0.678805</td>
#       <td id="T_ea635_row2_col4" class="data row2 col4" >1.889273</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea635_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_ea635_row3_col1" class="data row3 col1" >0.961538</td>
#       <td id="T_ea635_row3_col2" class="data row3 col2" >0.104011</td>
#       <td id="T_ea635_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_ea635_row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea635_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_ea635_row4_col1" class="data row4 col1" >1.453425</td>
#       <td id="T_ea635_row4_col2" class="data row4 col2" >1.057737</td>
#       <td id="T_ea635_row4_col3" class="data row4 col3" >0.165562</td>
#       <td id="T_ea635_row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea635_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_ea635_row5_col1" class="data row5 col1" >-1.336936</td>
#       <td id="T_ea635_row5_col2" class="data row5 col2" >0.562861</td>
#       <td id="T_ea635_row5_col3" class="data row5 col3" >1.392855</td>
#       <td id="T_ea635_row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea635_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_ea635_row6_col1" class="data row6 col1" >0.121668</td>
#       <td id="T_ea635_row6_col2" class="data row6 col2" >1.207603</td>
#       <td id="T_ea635_row6_col3" class="data row6 col3" >-0.002040</td>
#       <td id="T_ea635_row6_col4" class="data row6 col4" >1.627796</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea635_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_ea635_row7_col1" class="data row7 col1" >0.354493</td>
#       <td id="T_ea635_row7_col2" class="data row7 col2" >1.037528</td>
#       <td id="T_ea635_row7_col3" class="data row7 col3" >-0.385684</td>
#       <td id="T_ea635_row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ea635_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_ea635_row8_col1" class="data row8 col1" >1.686583</td>
#       <td id="T_ea635_row8_col2" class="data row8 col2" >-1.325963</td>
#       <td id="T_ea635_row8_col3" class="data row8 col3" >1.428984</td>
#       <td id="T_ea635_row8_col4" class="data row8 col4" >-2.089354</td>
#     </tr>
#     <tr>
#       <th id="T_ea635_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ea635_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_ea635_row9_col1" class="data row9 col1" >-0.129820</td>
#       <td id="T_ea635_row9_col2" class="data row9 col2" >0.631523</td>
#       <td id="T_ea635_row9_col3" class="data row9 col3" >-0.586538</td>
#       <td id="T_ea635_row9_col4" class="data row9 col4" >0.290720</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Interactive outputs
#
# ### Folium

# %%
import folium

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[45.3288, -121.6625],
    popup='Mt. Hood Meadows',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup='Some Other Location',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2899aac5a329e1ab6e53b2f4f92a1f9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2899aac5a329e1ab6e53b2f4f92a1f9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2899aac5a329e1ab6e53b2f4f92a1f9a = L.map(
#                 &quot;map_2899aac5a329e1ab6e53b2f4f92a1f9a&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdce3cc08f885a065e9faf0e31ea719e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2899aac5a329e1ab6e53b2f4f92a1f9a);
#
#
#             var marker_7744167c425d0edf0b40b919db530e68 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_2899aac5a329e1ab6e53b2f4f92a1f9a);
#
#
#             var icon_09838d7223c655ac504fdc8314c8878a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7744167c425d0edf0b40b919db530e68.setIcon(icon_09838d7223c655ac504fdc8314c8878a);
#
#
#         var popup_41ee5b2952a58f819d7f67a4db97ec96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5b04ddae43b98119ca37e58951b2c0ae = $(`&lt;div id=&quot;html_5b04ddae43b98119ca37e58951b2c0ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mt. Hood Meadows&lt;/div&gt;`)[0];
#             popup_41ee5b2952a58f819d7f67a4db97ec96.setContent(html_5b04ddae43b98119ca37e58951b2c0ae);
#
#
#         marker_7744167c425d0edf0b40b919db530e68.bindPopup(popup_41ee5b2952a58f819d7f67a4db97ec96)
#         ;
#
#
#
#
#             var marker_b8fc68ef85512052ad73105678995177 = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_2899aac5a329e1ab6e53b2f4f92a1f9a);
#
#
#             var icon_c13023f4c5cdc71bf9fcdb9e2463e972 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8fc68ef85512052ad73105678995177.setIcon(icon_c13023f4c5cdc71bf9fcdb9e2463e972);
#
#
#         var popup_ae8c04a72ccc52c603800afadc65728b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_56eb6106ca85d395b4d8e7e96acff2f0 = $(`&lt;div id=&quot;html_56eb6106ca85d395b4d8e7e96acff2f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#             popup_ae8c04a72ccc52c603800afadc65728b.setContent(html_56eb6106ca85d395b4d8e7e96acff2f0);
#
#
#         marker_b8fc68ef85512052ad73105678995177.bindPopup(popup_ae8c04a72ccc52c603800afadc65728b)
#         ;
#
#
#
#
#             var marker_a206a3835c3ec22a67945dc466226423 = L.marker(
#                 [45.33, -121.6823],
#                 {}
#             ).addTo(map_2899aac5a329e1ab6e53b2f4f92a1f9a);
#
#
#             var icon_f2322fca2495aacfff70645961e5b277 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a206a3835c3ec22a67945dc466226423.setIcon(icon_f2322fca2495aacfff70645961e5b277);
#
#
#         var popup_3fc38827fcade63601bfe8174e515db1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_19ff440e8f4475ea696d39cdcd34622a = $(`&lt;div id=&quot;html_19ff440e8f4475ea696d39cdcd34622a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Some Other Location&lt;/div&gt;`)[0];
#             popup_3fc38827fcade63601bfe8174e515db1.setContent(html_19ff440e8f4475ea696d39cdcd34622a);
#
#
#         marker_a206a3835c3ec22a67945dc466226423.bindPopup(popup_3fc38827fcade63601bfe8174e515db1)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Stdout

# %%
# The ! causes this to run as a shell command
# !jupyter -h
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: book bundlerextension console dejavu execute kernel
# kernelspec lab labextension labhub migrate nbclassic nbconvert nbextension
# notebook qtconsole run script server serverextension troubleshoot trust

# %% [markdown]
# ## Formatting code cells
#
# ### Scrolling cell outputs

# %%
for ii in range(40):
    print(f"this is output line {ii}")
# Out:
# this is output line 0
# this is output line 1
# this is output line 2
# this is output line 3
# this is output line 4
# this is output line 5
# this is output line 6
# this is output line 7
# this is output line 8
# this is output line 9
# this is output line 10
# this is output line 11
# this is output line 12
# this is output line 13
# this is output line 14
# this is output line 15
# this is output line 16
# this is output line 17
# this is output line 18
# this is output line 19
# this is output line 20
# this is output line 21
# this is output line 22
# this is output line 23
# this is output line 24
# this is output line 25
# this is output line 26
# this is output line 27
# this is output line 28
# this is output line 29
# this is output line 30
# this is output line 31
# this is output line 32
# this is output line 33
# this is output line 34
# this is output line 35
# this is output line 36
# this is output line 37
# this is output line 38
# this is output line 39

# %% [markdown]
# ### Scrolling cell inputs

# %%
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
b = "This line has no meaning"
print(b)
# Out:
# This line has no meaning
